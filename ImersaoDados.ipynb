# %% [markdown]
# <a href="https://colab.research.google.com/github/ducrz/Imersao-Dados/blob/main/ImersaoDados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url_dados="https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true";
dados=pd.read_csv(url_dados,compression='zip');
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['dose'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados['g-0']>0
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 23809     True
# 23810    False
# 23811     True
# 23812     True
# 23813    False
# Name: g-0, Length: 23814, dtype: bool

# %%
dados[dados['g-0'] > 0]
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %%
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# # DESAFIOS
#
# **DESAFIO 1:**
#
# Investigar por que a classe tratamento é tão desbalanceada.
#
# **Resposta:** A quantidade de tipos de drogas é grande, exigindo uma grande quantidade de testes com cada. O que acaba resultado em um número muito maior de testes feitos quando comparado aos de controle.

# %%
dados["tratamento"].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados_filtrados['droga'].value_counts()
# Out:
# cacb2b860    802
# 87d714366    718
# 5628cb3ee    187
# 9f80f3f77    150
# 8b87a7a83    123
#             ...
# 677c0e043      1
# d2c1d1a42      1
# 9cc1467b6      1
# 00251fc41      1
# 4cd924a5d      1
# Name: droga, Length: 3078, dtype: int64

# %%
dados['tratamento'].value_counts().plot.bar()

# %% [markdown]
# **DESAFIO 2:**
#
# Plotar as 5 últimas linhas da tabela.
#
# **Resposta:** Para exibir as últimas linhas da tabela é utilizado o tail.

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# **DESAFIO 3:**
#
# Proporção das classes tratamento.

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['dose'].value_counts().plot.pie()

# %% [markdown]
# **DESAFIO 4:**
#
# Quantos tipos de drogas foram investigados?
# **Resposta:** 3289

# %%
dados['droga'].unique().size
# Out:
# 3289

# %% [markdown]
# **DESAFIO 5:**
#
# Procurar na documentação o método query(pandas).
#
# **Resposta:** Utilizando o método query, é possível filtrar utilizando condições. Por exemplo filtrar somente os tratados com_droga,com 24 horas de tempo e dose D1.

# %%
dados.query('tempo == "24" & tratamento == "com_droga" & dose== "D1"')
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 5      id_001762a82  com_droga     24   D1  ...  1.2120  0.3765  0.7848  1.3990
# 36     id_00762e877  com_droga     24   D1  ...  0.5418  0.8407  0.3193  0.4817
# 39     id_0079d45d3  com_droga     24   D1  ... -2.7020 -2.2530 -4.8360 -0.6461
# 48     id_008b48693  com_droga     24   D1  ... -0.2725 -0.1511 -0.4635 -0.1365
# ...             ...        ...    ...  ...  ...     ...     ...     ...     ...
# 23787  id_ffcb7e365  com_droga     24   D1  ...  0.6259  0.8588  0.1258  0.4556
# 23796  id_ffe18c87f  com_droga     24   D1  ... -0.4029 -0.9694 -0.2315 -0.8074
# 23802  id_fff3976bd  com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23804  id_fff506720  com_droga     24   D1  ... -0.4097  0.2282 -0.3213 -0.0836
# 23812  id_fffcb9e7c  com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
#
# ...

# %% [markdown]
# **DESAFIO 06:**
#
# Renomear as colunas tirando o hífen.
#
# **Resposta:** existem vários métodos e funções que permitem retirar caracteres, como por exemplo o o str.replace, que é utilizdo em várias linguagens de programação diferentes.

# %%
dados.columns = dados.columns.str.replace("-","")
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# **DESAFIO 7:**
#
# Deixar os gráficos bonitos: alterar título e label.
#
# **Resposta:** Conforme dica do Professor, um boa saída é utilizar o Matplotlib.pyplot.

# %%
import matplotlib.pyplot as grafico

dados['tratamento'].value_counts().plot.bar()
grafico.title("Tratamentos",fontSize=21)
grafico.xlabel("Tipos Utilizados",fontSize=18)
grafico.ylabel("Quantidade Testada",fontSize=18)
grafico.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# **DESAFIO 08**
#
# Resumo do que você aprendeu com os dados.
#
# **Resposta:** Como filtrar informações de maneira eficiente e que permitam um melhor entendimento sobre aquilo que está sendo analisando, mesmo que não saiba a fundo sobre o que exatamente os dados são.

# %% [markdown]
# #Aula 02 | Estatísticas, visualização de dados e distribuições

# %%
mapa={'droga':'composto'}
dados.rename(columns=mapa,inplace=True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos= dados['composto'].value_counts().index[0:5]

# %%
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(8,6))

ax=sns.countplot(x= 'composto', data=dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 Compostos')
plt.show()

# %%
len(dados['g0'].unique())
# Out:
# 14367

# %%
dados['g0'].min()
# Out:
# -5.513

# %%
dados['g0'].max()
# Out:
# 10.0

# %%
dados['g0'].hist()

# %%
dados['g0'].hist(bins=50)

# %%
dados['g0'].hist(bins=100)

# %%
dados['g19'].hist(bins=100)

# %%
dados['g0'].min()
# Out:
# -5.513

# %%
dados['g0'].mean()
# Out:
# 0.24836629293692816

# %%
dados.describe()
# Out:
#               tempo            g0  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados[['g0','g1']]
# Out:
#            g0      g1
# 0      1.0620  0.5577
# 1      0.0743  0.4087
# 2      0.6280  0.5817
# 3     -0.5138 -0.2491
# 4     -0.3254 -0.4009
# ...       ...     ...
# 23809  0.1394 -0.0636
# 23810 -1.3260  0.3478
# 23811  0.3942  0.3756
# 23812  0.6660  0.2324
# 23813 -0.8598  1.0240
#
# [23814 rows x 2 columns]

# %%
dados.loc[0,'g0']
# Out:
# 1.062

# %%
dados.loc[:,'g0':'g771'].describe()
# Out:
#                  g0            g1  ...          g770          g771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
dados.loc[:, 'g0':'g771'].describe().T
# Out:
#         count      mean       std     min       25%      50%       75%     max
# g0    23814.0  0.248366  1.393399  -5.513 -0.473075 -0.00885  0.525700  10.000
# g1    23814.0 -0.095684  0.812363  -5.737 -0.562200 -0.04660  0.403075   5.039
# g2    23814.0  0.152253  1.035731  -9.104 -0.437750  0.07520  0.663925   8.257
# g3    23814.0  0.081971  0.950012  -5.998 -0.429575  0.00805  0.463400  10.000
# g4    23814.0  0.057347  1.032091  -6.369 -0.470925 -0.02690  0.465375  10.000
# ...       ...       ...       ...     ...       ...      ...       ...     ...
# g767  23814.0 -0.076251  1.115477 -10.000 -0.506200  0.00990  0.511175   6.317
# g768  23814.0  0.134162  0.951264  -4.269 -0.353100  0.00540  0.409075  10.000
# g769  23814.0 -0.128018  1.230636 -10.000 -0.544600  0.00060  0.498500   5.911
# g770  23814.0 -0.219210  1.326193 -10.000 -0.554400  0.02870  0.496400  10.000
# g771  23814.0  0.101524  1.417674 -10.000 -0.523800 -0.00650  0.536950  10.000
#
# [772 rows x 8 columns]

# %%
dados.loc[:, 'g0':'g771'].describe().T['mean'].hist(bins = 30)

# %%
dados.loc[:, 'g0':'g771'].describe().T['min'].hist(bins = 30)

# %%
dados.loc[:, 'g0':'g771'].describe().T['max'].hist(bins = 30)

# %%
dados.loc[:, 'c0':'c99'].describe().T['mean'].hist(bins = 50)

# %%
sns.boxplot(x='g0', data=dados)

# %%
sns.boxplot(x='g0', y='tratamento', data=dados)

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='g0', x='tratamento', data=dados)

# %% [markdown]
# **DESAFIO 09**
#
# Ordenar o gráfico countplot.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(8,6))

ax=sns.countplot(x='composto', data=dados.query('composto in @cod_compostos'),order = reversed(cod_compostos))
ax.set_title('Top 5 Compostos')
plt.show()

# %% [markdown]
# **DESAFIO 10**
#
# Melhorar a visualização.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(8,6))

ax=sns.countplot(x='composto', data=dados.query('composto in @cod_compostos'), order = reversed(cod_compostos))
ax.set_title('Top 5 Compostos',fontsize=18, fontweight='bold')
plt.xlabel('Compostos',fontsize=15, fontweight='bold')
plt.ylabel('Testes',fontsize=15, fontweight='bold')
# Out:
# Text(0, 0.5, 'Testes')

# %% [markdown]
# **DESAFIO 11**
#
# Plotar os histogramas com Seaborn

# %%
import seaborn as seaborn
import matplotlib.pyplot as plt

dados_filtrados = dados['g19']
seaborn.set()
ax = seaborn.histplot(dados_filtrados, bins = 30)
plt.show()

# %% [markdown]
# **DESAFIO 12**
#
# Estudar sobre as estatísticas retornadas no .describe()
#
# **Resposta:** Serve para gerar estatísticas descritivas.
#
# São possíveis de utilização as seguintes funções:
#
# count,mean,std,min,25%,50%,75%,max e dtype.

# %% [markdown]
# **DESAFIO 13**
#
# Refletir sobre a manipulação dos tamanhos das visualizações.
#
# **Resposta:** O tamanho da visualização deve ser adequado ao tipo de dado utilizado e a finalidade desejada para aquele gráfico

# %% [markdown]
# **DESAFIO 14:**
#
# Fazer outras análises com o boxplot e até com o histograma.

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y='c19', x='tratamento', data=dados)

# %%
dados.loc[:, 'c0':'c99'].describe().T['mean'].hist(bins = 30)

# %% [markdown]
# **DESAFIO 15:**
#
# Resumo do que você aprendeu com os dados.
#
# **Resposta:** Como usar Searbon e MatPlotLib e quais desafios são encontrados em análise de dados.

# %% [markdown]
# #Aula 03 - Correlações, causalidade e relações entre genes.

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize = True)
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.012640   0.150542
#      48         0.014403   0.168430
#      72         0.012892   0.151172
# D2   24         0.012808   0.150374
#      48         0.012808   0.150794
#      72         0.012808   0.150332

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize = 'index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados[['g0', 'g3']]
# Out:
#            g0      g3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
sns.scatterplot(x='g0',y='g3',data=dados)

# %%
sns.scatterplot(x = 'g0', y = 'g8', data = dados)

# %%
sns.lmplot(data = dados, x='g0', y='g8', line_kws = {'color': 'red'})

# %%
dados[['g0', 'g3']]
# Out:
#            g0      g3
# 0      1.0620 -0.6208
# 1      0.0743  0.0604
# 2      0.6280 -0.0764
# 3     -0.5138  0.5288
# 4     -0.3254  0.6919
# ...       ...     ...
# 23809  0.1394 -0.5080
# 23810 -1.3260  0.9905
# 23811  0.3942 -0.7389
# 23812  0.6660  0.2044
# 23813 -0.8598  0.7952
#
# [23814 rows x 2 columns]

# %%
sns.lmplot(data = dados, x='g0', y='g8', line_kws = {'color': 'red'}, col = 'tratamento')

# %%
sns.lmplot(data = dados, x='g0', y='g8', line_kws = {'color': 'red'}, col = 'tratamento', row = 'tempo')

# %%
dados.loc[:, 'g0':'g771'].corr()
# Out:
#             g0        g1        g2  ...      g769      g770      g771
# g0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...        ...       ...       ...  ...       ...       ...       ...
# g767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
import numpy as np
# Compute the correlation matrix
corr = dados.loc[:, 'g0':'g50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap,  center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
import numpy as np
# Compute the correlation matrix
corr_celular = dados.loc[:, 'c0':'c50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap,  center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# **DESAFIO 16:**
#
# Criar tabelas de frequência com o pandas.groupby().

# %%
dados.groupby(by=['dose', 'tempo'])['tratamento'].value_counts()
# Out:
# dose  tempo  tratamento
# D1    24     com_droga       3585
#              com_controle     301
#       48     com_droga       4011
#              com_controle     343
#       72     com_droga       3600
#              com_controle     307
# D2    24     com_droga       3581
#              com_controle     305
#       48     com_droga       3591
#              com_controle     305
#       72     com_droga       3580
#              com_controle     305
# Name: tratamento, dtype: int64

# %% [markdown]
# **DESAFIO 17:**
# Normalizar o crosstab pela coluna.

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados ['tratamento'], normalize = 'columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %% [markdown]
# **DESAFIO 18:**
# Explorar outros agregadores.

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values=dados['g0'], aggfunc='min')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24           -2.370     -5.183
#      48           -3.276     -5.420
#      72           -2.086     -5.261
# D2   24           -2.135     -5.233
#      48           -4.859     -4.567
#      72           -1.909     -5.513

# %%
pd.pivot_table(dados, index='tratamento', aggfunc='max')
# Out:
#                  c0     c1    c10    c11  ...    g98    g99            id  tempo
# tratamento                                ...
# com_controle  2.093  2.317  2.592  3.393  ...  2.867  4.146  id_fffc1c3f4     72
# com_droga     3.365  3.915  5.642  3.904  ...  7.311  5.400  id_ffffdd77b     72
#
# [2 rows x 876 columns]

# %% [markdown]
# **DESAFIO 19:**
#
# Explorar o melt.

# %%
pd.melt(dados, id_vars= ['tempo', 'dose','tratamento'])
# Out:
#           tempo dose    tratamento variable         value
# 0            24   D1     com_droga       id  id_000644bb2
# 1            72   D1     com_droga       id  id_000779bfc
# 2            48   D1     com_droga       id  id_000a6266a
# 3            48   D1     com_droga       id  id_0015fd391
# 4            72   D2     com_droga       id  id_001626bd3
# ...         ...  ...           ...      ...           ...
# 20813431     24   D2     com_droga      c99         0.468
# 20813432     24   D2     com_droga      c99        0.3689
# 20813433     48   D2  com_controle      c99        0.3808
# 20813434     24   D1     com_droga      c99         0.074
# 20813435     72   D1     com_droga      c99        -4.252
#
# [20813436 rows x 5 columns]

# %% [markdown]
# **DESAFIO 20:**
#
# Calcular e analisar a correlação entre G e C. Refletir sobre os efeitos biológicos.

# %%
c = pd.DataFrame(dados[dados['dose'] == 'D1'].loc[:,'c0':'c50'])
g = pd.DataFrame(dados[dados['dose'] == 'D1'].loc[:,'g0':'g50'])
g1 = pd.concat([g, c], axis =1, join = 'inner')
g1 = g1.corr()
corr = g1.loc['g0':'g50','c0':'c50']
corr
# Out:
#            c0        c1        c2  ...       c48       c49       c50
# g0  -0.623017 -0.634405 -0.647538  ... -0.606350 -0.626503 -0.603520
# g1   0.088438  0.080976  0.075728  ...  0.105079  0.136464  0.131174
# g2  -0.120350 -0.132486 -0.127077  ... -0.107563 -0.122778 -0.103499
# g3   0.026657 -0.014924 -0.006954  ...  0.013699  0.027149  0.040236
# g4  -0.342211 -0.330921 -0.344541  ... -0.307592 -0.312007 -0.314086
# g5   0.249706  0.240248  0.253822  ...  0.232364  0.243221  0.237369
# g6  -0.160182 -0.121942 -0.117460  ... -0.096327 -0.137799 -0.122607
# g7   0.542364  0.619943  0.630551  ...  0.610774  0.584330  0.568884
# g8   0.609272  0.592669  0.587203  ...  0.509610  0.570764  0.543014
# g9   0.483679  0.526990  0.543295  ...  0.516323  0.514255  0.503536
# g10  0.630494  0.685876  0.687049  ...  0.640187  0.654581  0.642782
# g11 -0.230474 -0.238853 -0.243346  ... -0.229311 -0.226822 -0.240207
# g12  0.420479  0.459162  0.457262  ...  0.436540  0.443212  0.446286
# ...

# %% [markdown]
# **DESAFIO 21:**
#
# Estudar o código que plota a matriz de correlação (heatmap).

# %%
# Compute the correlation matrix
corr_celular = dados.loc[:, 'g0':'g50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.8, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# **DESAFIO 22:**
# Resumo
#
# **Resposta:** Nesta aula aprendi como utilizar varios tipos de gráficos para plotagem, e também como utilizando-se de correlações é possível extrair informações relevantes sobre base de dados.

# %% [markdown]
# #Aula 04 | Merge de dados e análise de resultados

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %%
dados_resultados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
contagem_moa = dados_resultados.select_dtypes('int64').sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
contagem_moaid = dados_resultados.drop('id', axis=1).sum().sort_values(ascending=False)
contagem_moaid
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.sum()
# Out:
# id                                       id_000644bb2id_000779bfcid_000a6266aid_0015fd3...
# 5-alpha_reductase_inhibitor                                                             17
# 11-beta-hsd1_inhibitor                                                                  18
# acat_inhibitor                                                                          24
# acetylcholine_receptor_agonist                                                         190
#                                                                ...
# ubiquitin_specific_protease_inhibitor                                                    6
# vegfr_inhibitor                                                                        170
# vitamin_b                                                                               26
# vitamin_d_receptor_agonist                                                              39
# wnt_inhibitor                                                                           30
# ...

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultados.drop('id', axis=1).sum(axis=1).sort_values(ascending=False)
# Out:
# 21197    7
# 4849     7
# 19186    7
# 14316    7
# 20584    7
#         ..
# 6862     0
# 6861     0
# 11997    0
# 6859     0
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados.drop('id', axis=1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  wnt_inhibitor  n_moa
# 0  id_000644bb2                            0  ...              0      1
# 1  id_000779bfc                            0  ...              0      0
# 2  id_000a6266a                            0  ...              0      3
# 3  id_0015fd391                            0  ...              0      0
# 4  id_001626bd3                            0  ...              0      1
#
# [5 rows x 208 columns]

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] != 0)

dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
dados_combinados= pd.merge(dados, dados_resultados[['id','n_moa', 'ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...     c98     c99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:11]
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y = 'g0', x='composto')

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y = 'g0', x='composto',hue='ativo_moa')

# %% [markdown]
# **DESAFIO 23:**
#
# Encontrar o top 10 das ações do MOA(inibidor, agonista ...).

# %%
contagem_moa[0:10]
# Out:
# nfkb_inhibitor                    832
# proteasome_inhibitor              726
# cyclooxygenase_inhibitor          435
# dopamine_receptor_antagonist      424
# serotonin_receptor_antagonist     404
# dna_inhibitor                     402
# glutamate_receptor_antagonist     367
# adrenergic_receptor_antagonist    360
# cdk_inhibitor                     340
# egfr_inhibitor                    336
# dtype: int64

# %% [markdown]
# **DESAFIO 24**
#
# Criar a coluna eh_controle para quando na coluna tratamento == com_controle.

# %%
dados_combinados['eh_controle'] = (dados_combinados['tratamento'] == 'com_controle')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...     c99  n_moa  ativo_moa  eh_controle
# 0  id_000644bb2  com_droga     24   D1  ...  0.4176      1       True        False
# 1  id_000779bfc  com_droga     72   D1  ...  0.7371      0      False        False
# 2  id_000a6266a  com_droga     48   D1  ...  0.6931      3       True        False
# 3  id_0015fd391  com_droga     48   D1  ... -0.8154      0      False        False
# 4  id_001626bd3  com_droga     72   D2  ...  0.7125      1       True        False
#
# [5 rows x 880 columns]

# %% [markdown]
# **DESAFIO 25:**
#
# Criar três colunas para indicar o tempo 24, 48, 72.

# %%
dados_combinados['24'] = (dados_combinados['tempo'] == '24')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ... n_moa  ativo_moa  eh_controle     24
# 0  id_000644bb2  com_droga     24   D1  ...     1       True        False  False
# 1  id_000779bfc  com_droga     72   D1  ...     0      False        False  False
# 2  id_000a6266a  com_droga     48   D1  ...     3       True        False  False
# 3  id_0015fd391  com_droga     48   D1  ...     0      False        False  False
# 4  id_001626bd3  com_droga     72   D2  ...     1       True        False  False
#
# [5 rows x 881 columns]

# %%
dados_combinados['48'] = (dados_combinados['tempo'] == '48')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ... ativo_moa  eh_controle     24     48
# 0  id_000644bb2  com_droga     24   D1  ...      True        False  False  False
# 1  id_000779bfc  com_droga     72   D1  ...     False        False  False  False
# 2  id_000a6266a  com_droga     48   D1  ...      True        False  False  False
# 3  id_0015fd391  com_droga     48   D1  ...     False        False  False  False
# 4  id_001626bd3  com_droga     72   D2  ...      True        False  False  False
#
# [5 rows x 882 columns]

# %%
dados_combinados['72'] = (dados_combinados['tempo'] == '72')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ... eh_controle     24     48     72
# 0  id_000644bb2  com_droga     24   D1  ...       False  False  False  False
# 1  id_000779bfc  com_droga     72   D1  ...       False  False  False  False
# 2  id_000a6266a  com_droga     48   D1  ...       False  False  False  False
# 3  id_0015fd391  com_droga     48   D1  ...       False  False  False  False
# 4  id_001626bd3  com_droga     72   D2  ...       False  False  False  False
#
# [5 rows x 883 columns]

# %% [markdown]
# **DESAFIO 26**
#
# Estudar sobre combinações de DataFrame: https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %%
 from pandas.api.types import CategoricalDtype
 X = pd.Series(np.random.choice(["com_droga", "com_controle"], size=(10,)))
 X = X.astype(CategoricalDtype(categories=["com_droga", "com_controle"]))
 left = pd.DataFrame(
 {"X": X, "Y": np.random.choice(["24", "48", "72"], size=(10,))}
 )
 left
 left.dtypes
 right = pd.DataFrame(
 {
 "X": pd.Series(["com_droga", "com_controle"], dtype=CategoricalDtype(["com_droga", "com_controle"])),
 "Z": [1, 2],
  }
  )
 right
 right.dtypes
 result = pd.merge(left, right, how="outer")
 result
# Out:
#               X   Y  Z
# 0     com_droga  72  1
# 1  com_controle  24  2
# 2  com_controle  24  2
# 3  com_controle  24  2
# 4  com_controle  72  2
# 5  com_controle  72  2
# 6  com_controle  72  2
# 7  com_controle  48  2
# 8  com_controle  24  2
# 9  com_controle  24  2

# %% [markdown]
# **DESAFIO 27:**
#
# Fazer análise mais detalhada considerando tempo e dose para comparar as distribuições. Escolher uma droga e comparar com o controle.

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('composto == "df89a8e5a"'), y='g0', x='composto', hue='dose')

# %% [markdown]
# **DESAFIO 28:**
#
# Descobrir se temos algum composto que dependendo da configuração do experimento, ativa ou não ativa algum MOA

# %%
dados_combinados.query('composto == "df89a8e5a"')['ativo_moa'].value_counts()
# Out:
# False    6
# Name: ativo_moa, dtype: int64

# %% [markdown]
# **DESAFIO 29:**
#
# Descobrir se temos algum composto que dependendo da configuração do experimento, ativa MOAs diferentes.

# %%
dados_combinados.query('composto == "df89a8e5a"')['ativo_moa'].value_counts()
# Out:
# False    6
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('composto == "df89a8e5a"')
# Out:
#                  id tratamento  tempo dose  ... eh_controle     24     48     72
# 1      id_000779bfc  com_droga     72   D1  ...       False  False  False  False
# 5389   id_3a1a0a94a  com_droga     24   D2  ...       False  False  False  False
# 6070   id_416ba6804  com_droga     24   D1  ...       False  False  False  False
# 12328  id_84cfb2d4e  com_droga     48   D2  ...       False  False  False  False
# 14089  id_97b32c381  com_droga     48   D1  ...       False  False  False  False
# 19987  id_d6421128d  com_droga     72   D2  ...       False  False  False  False
#
# [6 rows x 883 columns]

# %% [markdown]
# **DESAFIO 30:**
#
# Resumo do que você aprendeu com os dados.
#
# **Resposta:**  Como criar colunas, como fazer merge entre base dados, como fazer comparações e como extrair informações mais detalhadas utilizando querys.

# %% [markdown]
# #Aula 05 - Machine Learning, Sci-kit Learning e desafios envolvidos

# %%
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ... eh_controle     24     48     72
# 0  id_000644bb2  com_droga     24   D1  ...       False  False  False  False
# 1  id_000779bfc  com_droga     72   D1  ...       False  False  False  False
# 2  id_000a6266a  com_droga     48   D1  ...       False  False  False  False
# 3  id_0015fd391  com_droga     48   D1  ...       False  False  False  False
# 4  id_001626bd3  com_droga     72   D2  ...       False  False  False  False
#
# [5 rows x 883 columns]

# %%
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa']

# %%
from sklearn.model_selection import train_test_split

x_treino, x_teste, y_treino, y_teste = train_test_split(x, y)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa'] 
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_rlogistica = LogisticRegression(max_iter=1000)
modelo_rlogistica.fit(x_treino, y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6264959059416334

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score

modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)
accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.6067604450976275

# %%
dados_combinados['ativo_moa'].value_counts(normalize=True)
# Out:
# True     0.60666
# False    0.39334
# Name: ativo_moa, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier


x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa'] 
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_arvore = DecisionTreeClassifier(max_depth = 3)
modelo_arvore.fit(x_treino, y_treino)
modelo_arvore.score(x_teste, y_teste)
# Out:
# 0.6105395758975436

# %%
from sklearn import tree

fig, ax = plt.subplots(figsize=(15, 10), facecolor='k')
tree.plot_tree(modelo_arvore,
               ax=ax,
               fontsize=10,
               rounded=True,
               filled=True,
               feature_names=x_treino.columns,
               class_names=['Não Ativado', 'Ativado'])

plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier


x = dados_combinados.select_dtypes('float64')
y = dados_combinados['ativo_moa'] 
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

teste=[]
treino=[]
for i in range(1,5):
    modelo_arvore = DecisionTreeClassifier(max_depth = i)
    modelo_arvore.fit(x_treino, y_treino)
    teste.append(modelo_arvore.score(x_teste, y_teste))
    treino.append(modelo_arvore.score(x_treino, y_treino))

# %%
teste
# Out:
# [0.6067604450976275,
#  0.6067604450976275,
#  0.6105395758975436,
#  0.6208272097417594]

# %%
treino
# Out:
# [0.6066348223190384,
#  0.6066348223190384,
#  0.6211222508004829,
#  0.6360820954280615]

# %%
sns.lineplot(x=range(1,5), y = teste, label='teste')
sns.lineplot(x=range(1,5), y = treino, label='treino')

# %%
pd.get_dummies(dados_combinados['tratamento'])
# Out:
#        com_controle  com_droga
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 23809             0          1
# 23810             0          1
# 23811             1          0
# 23812             0          1
# 23813             0          1
#
# [23814 rows x 2 columns]

# %%
pd.get_dummies(dados_combinados, columns=['tratamento', 'dose', 'tempo'])
# Out:
#                  id   composto      g0  ...  tempo_24  tempo_48  tempo_72
# 0      id_000644bb2  b68db1d53  1.0620  ...         1         0         0
# 1      id_000779bfc  df89a8e5a  0.0743  ...         0         0         1
# 2      id_000a6266a  18bb41b2c  0.6280  ...         0         1         0
# 3      id_0015fd391  8c7f86626 -0.5138  ...         0         1         0
# 4      id_001626bd3  7cbed3131 -0.3254  ...         0         0         1
# ...             ...        ...     ...  ...       ...       ...       ...
# 23809  id_fffb1ceed  df1d0a5a1  0.1394  ...         1         0         0
# 23810  id_fffb70c0c  ecf3b6b74 -1.3260  ...         1         0         0
# 23811  id_fffc1c3f4  cacb2b860  0.3942  ...         0         1         0
# 23812  id_fffcb9e7c  8b87a7a83  0.6660  ...         1         0         0
# 23813  id_ffffdd77b  972f41291 -0.8598  ...         0         0         1
#
# [23814 rows x 887 columns]

# %%
dados_combinados.drop(['id', 'n_moa', 'ativo_moa','composto'], axis=1)
# Out:
#          tratamento  tempo dose      g0  ...  eh_controle     24     48     72
# 0         com_droga     24   D1  1.0620  ...        False  False  False  False
# 1         com_droga     72   D1  0.0743  ...        False  False  False  False
# 2         com_droga     48   D1  0.6280  ...        False  False  False  False
# 3         com_droga     48   D1 -0.5138  ...        False  False  False  False
# 4         com_droga     72   D2 -0.3254  ...        False  False  False  False
# ...             ...    ...  ...     ...  ...          ...    ...    ...    ...
# 23809     com_droga     24   D2  0.1394  ...        False  False  False  False
# 23810     com_droga     24   D2 -1.3260  ...        False  False  False  False
# 23811  com_controle     48   D2  0.3942  ...         True  False  False  False
# 23812     com_droga     24   D1  0.6660  ...        False  False  False  False
# 23813     com_droga     72   D1 -0.8598  ...        False  False  False  False
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier


x = dados_combinados.drop(['id', 'n_moa', 'ativo_moa', 'composto'], axis=1)
x = pd.get_dummies(x, columns=['tratamento', 'dose', 'tempo'])
y = dados_combinados['ativo_moa'] 
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

modelo_randomforest = RandomForestClassifier()
modelo_randomforest.fit(x_treino, y_treino)
modelo_randomforest.score(x_teste, y_teste)
# Out:
# 0.6869619987402897

# %% [markdown]
# **DESAFIO 31:**
# Tente outros modelos ou mude os parâmetros dos modelos que testamos em aula.

# %%
modelo_rlogistica = LogisticRegression(solver='newton-cg')
modelo_rlogistica.fit(x_treino, y_treino)
modelo_rlogistica.score(x_teste, y_teste)
# Out:
# 0.6644971656519001

# %% [markdown]
# **DESAFIO 32:**
# Estude a documentação do Sklearn.

# %% [markdown]
# **DESAFIO 33:**
# Pesquisar o fluxograma 'Escolhendo o melhor modelo' choosing the right estimator

# %% [markdown]
# **DESAFIO 34:**
# Teste outros problemas (perguntas). 0, 1 ou +

# %%
x = dados_combinados.loc[:,'g0':'c99']

# %%
y=dados_combinados['tempo'].map({24:0,48:1,72:2})

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y, random_state=376)

# %%
modelo_rlogistica2 = LogisticRegression(solver='newton-cg')
modelo_rlogistica2.fit(x_treino, y_treino)
modelo_rlogistica2.score(x_teste, y_teste)
# Out:
# 0.686122191895864

# %%
modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)
accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.3464203233256351

# %% [markdown]
# **DESAFIO 35:**
# Escolha a droga mais utilizada e tente criar um modelo para prever está label.

# %%
dados_combinados['composto'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 3e7f719a5       1
# 209a68d23       1
# fb69fd749       1
# b36078dd2       1
# dac782c74       1
# Name: composto, Length: 3289, dtype: int64

# %%
dt_temp = dados_combinados.query('composto in ["8b87a7a83", "5628cb3ee"]')

# %%
x = dt_temp.loc[:,'g0':'g10']

# %%
y = dt_temp['composto'].map({'8b87a7a83': 0, '5628cb3ee': 1})

# %%
sns.countplot(y=y)

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.2, stratify=y,random_state=376)

# %%
modelo_rlogistica2 = LogisticRegression()
modelo_rlogistica2.fit(x_treino, y_treino)
modelo_rlogistica2.score(x_teste, y_teste)
# Out:
# 0.9382716049382716

# %%
modelo_dummy = DummyClassifier('most_frequent')
modelo_dummy.fit(x_treino, y_treino)
previsao_dummy = modelo_dummy.predict(x_teste)
accuracy_score(y_teste, previsao_dummy)
# Out:
# 0.5061728395061729

# %% [markdown]
# **DESAFIO 36:**
# Resumo do que você aprendeu com os dados

# %% [markdown]
# **Resposta:** Esta aula teve uma ótima introdução sobre Machine Learning, como aplicá-la para facilitar a resolução de problemas, como treinar e aumentar a eficácia.
